# %%
URL = r'https://sussan.blob.core.windows.net/mammograms/manifest-1661677592968/CBIS-DDSM/Calc-Test_P_00038_LEFT_CC/08-29-2017-DDSM-NA-96009/1.000000-full-mammogram-images-63992/1-1.dcm?sp=racwdyti&st=2022-09-01T10:19:27Z&se=2022-09-01T18:19:27Z&spr=https&sv=2021-06-08&sr=b&sig=ZkwxyrC1TfT6IGWp67VluSvGP0wjCDeIaZPjY8A1sgw%3D'

import pydicom as dicom
import matplotlib.pylab as plt

# specify your image path
image_path = '/content/1-1.dcm'
ds = dicom.dcmread(URL)#imae_path)

plt.imshow(ds.pixel_array)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-b47ffcf7fdf0> in <module>
#       6 # specify your image path
#       7 image_path = '/content/1-1.dcm'
# ----> 8 ds = dicom.dcmread(URL)#imae_path)
#       9
#      10 plt.imshow(ds.pixel_array)
#
# /usr/local/lib/python3.7/dist-packages/pydicom/filereader.py in dcmread(fp, defer_size, stop_before_pixels, force, specific_tags)
#     991         caller_owns_file = False
#     992         logger.debug("Reading file '{0}'".format(fp))
# --> 993         fp = open(fp, 'rb')
#     994     elif fp is None or not hasattr(fp, "read") or not hasattr(fp, "seek"):
#     995         raise TypeError("dcmread: Expected a file path or a file-like, "
#
# ...

# %%
pip install pydicom
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 2.0 MB 13.7 MB/s
# ...

# %%
try:
  # %tensorflow_version 2.x 
except Exception:
  pass

# !pip install tensorflow-io
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 25.0 MB 1.5 MB/s
# ...
#      |████████████████████████████████| 2.4 MB 60.6 MB/s
# ...
#   Attempting uninstall: tensorflow-io-gcs-filesystem
#     Found existing installation: tensorflow-io-gcs-filesystem 0.26.0
#     Uninstalling tensorflow-io-gcs-filesystem-0.26.0:
#       Successfully uninstalled tensorflow-io-gcs-filesystem-0.26.0
# ...

# %%
# !npm install azurite@2.7.0
# Out:
# npm WARN deprecated request@2.87.0: request has been deprecated, see https://github.com/request/request/issues/3142
# npm WARN deprecated uuid@3.4.0: Please upgrade  to version 7 or higher.  Older versions may use Math.random() in certain circumstances, which is known to be problematic.  See https://v8.dev/blog/math-random for details.
# npm WARN deprecated har-validator@5.0.3: this library is no longer supported
# npm WARN saveError ENOENT: no such file or directory, open '/content/package.json'
# npm notice created a lockfile as package-lock.json. You should commit this file.
# npm WARN enoent ENOENT: no such file or directory, open '/content/package.json'
# npm WARN content No description
# npm WARN content No repository field.
# npm WARN content No README data
# npm WARN content No license field.
#
# + azurite@2.7.0
# added 125 packages from 144 contributors and audited 125 packages in 12.478s
#
# 7 packages are looking for funding
#   run `npm fund` for details
#
# ...

# %%
# The path for npm might not be exposed in PATH env,
# you can find it out through 'npm bin' command
npm_bin_path = get_ipython().getoutput('npm bin')[0]
print('npm bin path: ', npm_bin_path)

# Run `azurite-blob -s` as a background process. 
# IPython doesn't recognize `&` in inline bash cells.
get_ipython().system_raw(npm_bin_path + '/' + 'azurite-blob -s &')
# Out:
# npm bin path:  /content/node_modules/.bin

# %%
import os
import tensorflow as tf
import tensorflow_io as tfio

# Switch to False to use Azure Storage instead:
use_emulator = False

if use_emulator:
  os.environ['TF_AZURE_USE_DEV_STORAGE'] = '1'
  account_name = 'devstoreaccount1'
else:
  # Replace <key> with Azure Storage Key, and <account> with Azure Storage Account
  os.environ['TF_AZURE_STORAGE_KEY'] = 's8qd5f+WBfGdJQrdDHbEfCq8+kyA+MtsNnf0tOJO3e2QA5udEu54OsLkfxyu7KFMC/Nxi/8rCt/C+AStnpxBJw=='
  account_name = 'sussan'

  # Alternatively, you can use a shared access signature (SAS) to authenticate with the Azure Storage Account
  # os.environ['TF_AZURE_STORAGE_SAS'] = '<your sas>'
  # account_name = '<account>'

# %%
pathname = 'az://{}/mammograms'.format(account_name)
tf.io.gfile.mkdir(pathname)

filename = pathname + '/manifest-1661677592968/CBIS-DDSM/Calc-Test_P_00038_LEFT_CC/08-29-2017-DDSM-NA-96009/1.000000-full mammogram images-63992/1-1.dcm'
# with tf.io.gfile.GFile(filename, mode='w') as w:
#   w.write("Hello, world!")

# https://sussan.blob.core.windows.net/mammograms/manifest-1661677592968/CBIS-DDSM/Calc-Test_P_00038_LEFT_CC/08-29-2017-DDSM-NA-96009/1.000000-full mammogram images-63992/1-1.dcm

with tf.io.gfile.GFile(filename, mode='r') as r:
  print(dicom.dcmread)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-9fb27be5b7ad> in <module>
#       9
#      10 with tf.io.gfile.GFile(filename, mode='r') as r:
# ---> 11   print(dicom.dcmread(filename))
#
# /usr/local/lib/python3.7/dist-packages/pydicom/filereader.py in dcmread(fp, defer_size, stop_before_pixels, force, specific_tags)
#     991         caller_owns_file = False
#     992         logger.debug("Reading file '{0}'".format(fp))
# --> 993         fp = open(fp, 'rb')
#     994     elif fp is None or not hasattr(fp, "read") or not hasattr(fp, "seek"):
#     995         raise TypeError("dcmread: Expected a file path or a file-like, "
#
# FileNotFoundError: [Errno 2] No such file or directory: 'az://sussan/mammograms/manifest-1661677592968/CBIS-DDSM/Calc-Test_P_00038_LEFT_CC/08-29-2017-DDSM-NA-96009/1.000000-full mammogram images-63992/1-1.dcm'
