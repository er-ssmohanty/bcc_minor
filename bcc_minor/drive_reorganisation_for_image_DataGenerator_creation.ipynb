# %%
import os
import pandas as pd

# %%
mass_train=pd.read_csv('/content/drive/MyDrive/mass_case_description_train_set.csv')
mass_train['studyid']=mass_train['image file path'].apply(lambda x: x.split('/')[1])
mass_train['seriesid']=mass_train['image file path'].apply(lambda x: x.split('/')[2])
feature_label_train_mass=mass_train[['studyid','pathology']]

# %%
os.chdir("/content/drive/MyDrive/cbis_ddsm")

# %%
os.listdir()
# Out:
# ['mass', '.ipynb_checkpoints', 'calc']

# %%
os.chdir("mass")

# %%
os.listdir()
# Out:
# ['train', 'test']

# %%
os.listdir("train")

# %%
os.listdir("train")[0]
# Out:
# '1.3.6.1.4.1.9590.100.1.2.319478999311971442426185353560182990988.png'

# %%
feature_label_train_mass.studyid[0]+'.png'
# Out:
# '1.3.6.1.4.1.9590.100.1.2.422112722213189649807611434612228974994.png'

# %%
os.chdir("train")

# %%
len(os.listdir())
# Out:
# 553

# %%
os.listdir()
# Out:
# ['train', 'test']

# %%
os.mkdir("benign")
os.mkdir("malignant")

# %%
len(os.listdir())
# Out:
# 555

# %%
os.getcwd()
# Out:
# '/content/drive/MyDrive/cbis_ddsm/mass/train'

# %%
malig=feature_label_train_mass[feature_label_train_mass.pathology=='MALIGNANT']
benig=feature_label_train_mass[feature_label_train_mass.pathology=='BENIGN']
bg_wc=feature_label_train_mass[feature_label_train_mass.pathology=='BENIGN_WITHOUT_CALLBACK']

# %%
benig.shape
# Out:
# (577, 2)

# %%
malig.shape
# Out:
# (637, 2)

# %%
for i in range(637):
  res=malig.iloc[i,0]+'.png' in os.listdir()
  if res==False:
    print(i)
    break
# Out:
# 272

# %%
for i in range(577):
  res=benig.iloc[i,0]+'.png' in os.listdir()
  if res==False:
    print(i)
    break
# Out:
# 278

# %%
os.listdir()[0][:-4]
# Out:
# '1.3.6.1.4.1.9590.100.1.2.319478999311971442426185353560182990988'

# %%
res
# Out:
# False

# %%
for i in range(malig.shape[0]):
  curr_=malig.iloc[i,0]+'.png' 
  res = curr_ in os.listdir()
  if res==False:
    print(i)
    print(curr_)
    print(res)
    break
  # os.rename("")
# Out:
# 272
# 1.3.6.1.4.1.9590.100.1.2.362951904211859693103191131021298491548.png
# False

# %%
"train/"+curr_
# Out:
# 'train/1.3.6.1.4.1.9590.100.1.2.362951904211859693103191131021298491548.png'

# %%
a[1]
# Out:
# '1.3.6.1.4.1.9590.100.1.2.319478999311971442426185353560182990988.png'

# %%
a=malig.iloc[:2,0]+'.png'

# %%
i
# Out:
# '1.3.6.1.4.1.9590.100.1.2.322851018411213611731661082961359065216png'

# %%
pwd
# Out:
# '/content/drive/MyDrive/cbis_ddsm/mass/train'

# %%
malignant_images=malig.studyid+'.png'
for i in malignant_images:
  if i in os.listdir():
    print(len(os.listdir()))
    os.rename(i,"malignant/"+i)

# %%
benign_images.shape
# Out:
# (577,)

# %%
benign_images=benig.studyid+'.png'
for i in benign_images:
  if i in os.listdir():
    print(len(os.listdir()))
    os.rename(i,"benign/"+i)

# %%
mkdir benig_wo_callback

# %%
bgwc_images=bg_wc.studyid+'.png'
for i in bgwc_images:
  if i in os.listdir():
    print(len(os.listdir()))
    os.rename(i,"benig_wo_callback/"+i)

# %%
len(os.listdir("benign"))
# Out:
# 262

# %%
cd ..
# Out:
# /content/drive/MyDrive/cbis_ddsm/mass/train

# %%
remnant

# %%
len(os.listdir("malignant"))
# Out:
# 256

# %%
mkdir train

# %%
cd /content/drive/MyDrive/backup/cbis_ddsm_backup/mass/train
# Out:
# /content/drive/MyDrive/backup/cbis_ddsm_backup/mass/train

# %%
cd /content/drive/MyDrive/cbis_ddsm/mass/train
# Out:
# /content/drive/MyDrive/cbis_ddsm/mass/train

# %%
cp *.png /content/drive/MyDrive/backup/cbis_ddsm_backup/mass/train

# %%
len(os.listdir())
# Out:
# 36

# %%
remnant=os.listdir()

# %%
remnant=remnant[:-2]

# %%
remnant

# %%
feature_label_train_mass.pathology.value_counts()
# Out:
# MALIGNANT                  637
# BENIGN                     577
# BENIGN_WITHOUT_CALLBACK    104
# Name: pathology, dtype: int64

# %%
ls
# Out:
# benign/  benig_wo_callback/  malignant/

# %%
for i in os.listdir():
  print(len(os.listdir(i)))
# Out:
# 262
# 256
# 34

# %%
262+256+34
# Out:
# 552

# %%
len(os.listdir("/content/drive/MyDrive/backup/cbis_ddsm_backup/mass/train"))
# Out:
# 552
