# %% [markdown]
# ## Clone GitHub repository

# %%
# !git clone https://github.com/himanshurawlani/fully_convolutional_network.git
# Out:
# Cloning into 'fully_convolutional_network'...
# remote: Enumerating objects: 85, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 85 (delta 7), reused 13 (delta 4), pack-reused 60
# Unpacking objects: 100% (85/85), done.

# %% [markdown]
# ## Change working directory

# %%
import os
os.chdir('fully_convolutional_network')
print(os.getcwd())
print(os.listdir())
# Out:
# /content/fully_convolutional_network
# ['README.md', '.git', 'inference.py', 'model.py', 'colab_notebook', 'data.py', 'flower_classifier', 'train.py', 'generator.py', 'snapshots', 'test_images', 'LICENSE', 'export_savedmodel.py']

# %% [markdown]
# ## Download and process dataset using utils.py

# %%
# !python data.py
# Out:
# Downloading data from http://download.tensorflow.org/example_images/flower_photos.tgz
# 228813984/228813984 [==============================] - 2s 0us/step
# Downloaded and extracted at ./datasets/flower_photos
# Copying images for sunflowers...
# Copying images for tulips...
# Copying images for dandelion...
# Copying images for roses...
# Copying images for daisy...
# Training dataset stats:
#
# --> Images in sunflowers: 500
# --> Images in tulips: 500
# --> Images in dandelion: 500
# --> Images in roses: 500
# --> Images in daisy: 500
# Validation dataset stats:
# --> Images in sunflowers: 100
# --> Images in tulips: 100
# --> Images in dandelion: 100
# --> Images in roses: 100
# --> Images in daisy: 100
#
# AVG_IMG_HEIGHT: 325
# AVG_IMG_WIDTH: 436
# MIN_HEIGHT: 177
# MIN_WIDTH: 143
# MAX_HEIGHT: 442
# MAX_WIDTH: 1024

# %% [markdown]
# ## Train the FCN network

# %%
# !python train.py
# Out:
# 2022-11-05 16:19:28.411482: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, None, 3)]   0
#
#  conv2d (Conv2D)             (None, None, None, 32)    896
#
#  dropout (Dropout)           (None, None, None, 32)    0
#
#  batch_normalization (BatchN  (None, None, None, 32)   128
#  ormalization)
#
#  activation (Activation)     (None, None, None, 32)    0
#
#  conv2d_1 (Conv2D)           (None, None, None, 64)    18496
#
#  dropout_1 (Dropout)         (None, None, None, 64)    0
#
#  batch_normalization_1 (Batc  (None, None, None, 64)   256
#  hNormalization)
#
#  activation_1 (Activation)   (None, None, None, 64)    0
#
#  conv2d_2 (Conv2D)           (None, None, None, 128)   73856
#
#  dropout_2 (Dropout)         (None, None, None, 128)   0
#
#  batch_normalization_2 (Batc  (None, None, None, 128)  512
#  hNormalization)
#
#  activation_2 (Activation)   (None, None, None, 128)   0
#
#  conv2d_3 (Conv2D)           (None, None, None, 256)   295168
#
#  dropout_3 (Dropout)         (None, None, None, 256)   0
#
#  batch_normalization_3 (Batc  (None, None, None, 256)  1024
#  hNormalization)
#
#  activation_3 (Activation)   (None, None, None, 256)   0
#
#  conv2d_4 (Conv2D)           (None, None, None, 512)   1180160
#
#  dropout_4 (Dropout)         (None, None, None, 512)   0
#
#  batch_normalization_4 (Batc  (None, None, None, 512)  2048
#  hNormalization)
#
#  activation_4 (Activation)   (None, None, None, 512)   0
#
#  conv2d_5 (Conv2D)           (None, None, None, 64)    32832
#
#  dropout_5 (Dropout)         (None, None, None, 64)    0
#
#  batch_normalization_5 (Batc  (None, None, None, 64)   256
#  hNormalization)
#
#  activation_5 (Activation)   (None, None, None, 64)    0
#
#  conv2d_6 (Conv2D)           (None, None, None, 5)     325
#
#  dropout_6 (Dropout)         (None, None, None, 5)     0
#
#  batch_normalization_6 (Batc  (None, None, None, 5)    20
#  hNormalization)
#
#  global_max_pooling2d (Globa  (None, 5)                0
#  lMaxPooling2D)
#
#  activation_6 (Activation)   (None, 5)                 0
#
# =================================================================
# Total params: 1,605,977
# Trainable params: 1,603,855
# Non-trainable params: 2,122
# _________________________________________________________________
# None
# Total number of layers: 30
# /usr/local/lib/python3.7/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# train.py:20: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   validation_steps=len(val_generator))
# Epoch 1/50
# tcmalloc: large alloc 1888034816 bytes == 0x58e36000 @  0x7fe800bfd1e7 0x7fe7d569816a 0x7fe7d8710be3 0x7fe7d8bf3736 0x7fe7d8c431b8 0x7fe7d8c44db3 0x7fe7d8c461e2 0x7fe7d8c480df 0x7fe7d8c4ccd2 0x7fe7d8c4d088 0x7fe7cce1f64b 0x7fe7ccdc6761 0x7fe7dab0bdd5 0x7fe7dab09b03 0x7fe7cd50d33b 0x7fe8005c16db 0x7fe8008fa61f
#   1/313 [..............................] - ETA: 1:54:02 - loss: 2.9241 - accuracy: 0.0000e+00tcmalloc: large alloc 1494876160 bytes == 0x4d81a000 @  0x7fe800bfd1e7 0x7fe7d569816a 0x7fe7d8710be3 0x7fe7d8bf3736 0x7fe7d8c431b8 0x7fe7d8c44db3 0x7fe7d8c461e2 0x7fe7d8c480df 0x7fe7d8c4ccd2 0x7fe7d8c4d088 0x7fe7cce1f64b 0x7fe7ccdc6761 0x7fe7dab0bdd5 0x7fe7dab09b03 0x7fe7cd50d33b 0x7fe8005c16db 0x7fe8008fa61f
#   2/313 [..............................] - ETA: 1:18:29 - loss: 2.4730 - accuracy: 0.0625    tcmalloc: large alloc 1504059392 bytes == 0x46c88000 @  0x7fe800bfd1e7 0x7fe7d569816a 0x7fe7d8710be3 0x7fe7d8bf3736 0x7fe7d8c431b8 0x7fe7d8c44db3 0x7fe7d8c461e2 0x7fe7d8c480df 0x7fe7d8c4ccd2 0x7fe7d8c4d088 0x7fe7cce1f64b 0x7fe7ccdc6761 0x7fe7dab0bdd5 0x7fe7dab09b03 0x7fe7cd50d33b 0x7fe8005c16db 0x7fe8008fa61f
#   4/313 [..............................] - ETA: 1:18:10 - loss: 2.2338 - accuracy: 0.1250tcmalloc: large alloc 1696047104 bytes == 0x5737c000 @  0x7fe800bfd1e7 0x7fe7d569816a 0x7fe7d8710be3 0x7fe7d8bf3736 0x7fe7d8c431b8 0x7fe7d8c44db3 0x7fe7d8c461e2 0x7fe7d8c480df 0x7fe7d8c4ccd2 0x7fe7d8c4d088 0x7fe7cce1f64b 0x7fe7ccdc6761 0x7fe7dab0bdd5 0x7fe7dab09b03 0x7fe7cd50d33b 0x7fe8005c16db 0x7fe8008fa61f
#  19/313 [>.............................] - ETA: 1:18:45 - loss: 2.0595 - accuracy: 0.1711tcmalloc: large alloc 1769144320 bytes == 0x59a54000 @  0x7fe800bfd1e7 0x7fe7d569816a 0x7fe7d8710be3 0x7fe7d8bf3736 0x7fe7d8c431b8 0x7fe7d8c44db3 0x7fe7d8c461e2 0x7fe7d8c480df 0x7fe7d8c4ccd2 0x7fe7d8c4d088 0x7fe7cce1f64b 0x7fe7ccdc6761 0x7fe7dab0bdd5 0x7fe7dab09b03 0x7fe7cd50d33b 0x7fe8005c16db 0x7fe8008fa61f
#  41/313 [==>...........................] - ETA: 1:12:14 - loss: 2.0036 - accuracy: 0.2073tcmalloc: large alloc 1938292736 bytes == 0x5f426000 @  0x7fe800bfd1e7 0x7fe7d569816a 0x7fe7d8710be3 0x7fe7d8bf3736 0x7fe7d8c431b8 0x7fe7d8c44db3 0x7fe7d8c461e2 0x7fe7d8c480df 0x7fe7d8c4ccd2 0x7fe7d8c4d088 0x7fe7cce1f64b 0x7fe7ccdc6761 0x7fe7dab0bdd5 0x7fe7dab09b03 0x7fe7cd50d33b 0x7fe8005c16db 0x7fe8008fa61f
# 101/313 [========>.....................] - ETA: 56:43 - loss: 1.9162 - accuracy: 0.2215tcmalloc: large alloc 2186412032 bytes == 0x67824000 @  0x7fe800bfd1e7 0x7fe7d569816a 0x7fe7d8710be3 0x7fe7d8bf3736 0x7fe7d8c431b8 0x7fe7d8c44db3 0x7fe7d8c461e2 0x7fe7d8c480df 0x7fe7d8c4ccd2 0x7fe7d8c4d088 0x7fe7cce1f64b 0x7fe7ccdc6761 0x7fe7dab0bdd5 0x7fe7dab09b03 0x7fe7cd50d33b 0x7fe8005c16db 0x7fe8008fa61f
# 313/313 [==============================] - ETA: 0s - loss: 1.6481 - accuracy: 0.3091 2022-11-05 17:48:35.576201: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 691445760 exceeds 10% of free system memory.
# tcmalloc: large alloc 3111624704 bytes == 0x7d8b4000 @  0x7fe800bfd1e7 0x7fe7d569816a 0x7fe7d8710be3 0x7fe7d8bf3736 0x7fe7d8c431b8 0x7fe7d8c44db3 0x7fe7d8c461e2 0x7fe7d8c480df 0x7fe7d8c4ccd2 0x7fe7d8c4d088 0x7fe7cce1f64b 0x7fe7ccdc6761 0x7fe7dab0bdd5 0x7fe7dab09b03 0x7fe7cd50d33b 0x7fe8005c16db 0x7fe8008fa61f
# 2022-11-05 17:48:37.442462: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 691445760 exceeds 10% of free system memory.
# Traceback (most recent call last):
#   File "train.py", line 39, in <module>
#     history = train(model, train_generator, val_generator, epochs=EPOCHS)
#   File "train.py", line 20, in train
#     validation_steps=len(val_generator))
#   File "/usr/local/lib/python3.7/dist-packages/keras/engine/training.py", line 2274, in fit_generator
#     initial_epoch=initial_epoch)
#   File "/usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/usr/local/lib/python3.7/dist-packages/keras/callbacks.py", line 1488, in _get_file_path
#     f'Failed to format this callback filepath: "{self.filepath}". '
# KeyError: 'Failed to format this callback filepath: "./snapshots/model_epoch_{epoch:02d}_loss_{loss:.2f}_acc_{acc:.2f}_val_loss_{val_loss:.2f}_val_acc_{val_acc:.2f}.h5". Reason: \'acc\''

# %% [markdown]
# ## Download Snapshot
# Download the best snapshot according to the metrics. Use the "Files" tab in Google Colab to open folder view and navigate to the snapshots folder.

# %% [markdown]
# ## Edit scripts
# In the Files tab, you can double click on any ".py" to edit it and save it within Google Colab.
