# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cz=pd.read_csv("/content/cubic_zirconia.csv",index_col=0)

# %% [markdown]
# Let's see how the dataframe looks like.

# %%
cz.head()
# Out:
#    carat        cut color clarity  depth  table     x     y     z  price
# 1   0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29  2.66    499
# 2   0.33    Premium     G      IF   60.8   58.0  4.42  4.46  2.70    984
# 3   0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12  3.78   6289
# 4   0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80  2.96   1082
# 5   0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43  2.65    779

# %% [markdown]
# Now we should examine the datatypes of different series of this dataframe.

# %%
cz.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26967 entries, 1 to 26967
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    26967 non-null  float64
#  1   cut      26967 non-null  object
#  2   color    26967 non-null  object
#  3   clarity  26967 non-null  object
#  4   depth    26270 non-null  float64
#  5   table    26967 non-null  float64
#  6   x        26967 non-null  float64
#  7   y        26967 non-null  float64
#  8   z        26967 non-null  float64
#  9   price    26967 non-null  int64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 2.3+ MB

# %% [markdown]
# Let's see the frequency distribution of each categorical variables.

# %%
for i in ['cut','color','clarity']:
  print(cz[i].value_counts())
  print("----------------------")
# Out:
# Ideal        10816
# Premium       6899
# Very Good     6030
# Good          2441
# Fair           781
# Name: cut, dtype: int64
# ----------------------
# G    5661
# E    4917
# F    4729
# H    4102
# D    3344
# I    2771
# J    1443
# Name: color, dtype: int64
# ----------------------
# SI1     6571
# VS2     6099
# SI2     4575
# VS1     4093
# VVS2    2531
# VVS1    1839
# IF       894
# I1       365
# Name: clarity, dtype: int64
# ----------------------

# %% [markdown]
# Now we'll generate descriptive statistics of numeric variables of the dataframe `cz`.

# %%
cz.describe()
# Out:
#               carat         depth         table             x             y  \
# count  26967.000000  26270.000000  26967.000000  26967.000000  26967.000000
# mean       0.798375     61.745147     57.456080      5.729854      5.733569
# std        0.477745      1.412860      2.232068      1.128516      1.166058
# min        0.200000     50.800000     49.000000      0.000000      0.000000
# 25%        0.400000     61.000000     56.000000      4.710000      4.710000
# 50%        0.700000     61.800000     57.000000      5.690000      5.710000
# 75%        1.050000     62.500000     59.000000      6.550000      6.540000
# max        4.500000     73.600000     79.000000     10.230000     58.900000
#
#                   z         price
# count  26967.000000  26967.000000
# mean       3.538057   3939.518115
# std        0.720624   4024.864666
# min        0.000000    326.000000
# 25%        2.900000    945.000000
# 50%        3.520000   2375.000000
# 75%        4.040000   5360.000000
# ...

# %% [markdown]
# We should now have a look at the different numeric variables of the dataframe correlate with each other.

# %%
cz.corr()
# Out:
#           carat     depth     table         x         y         z     price
# carat  1.000000  0.035364  0.181685  0.976368  0.941071  0.940640  0.922416
# depth  0.035364  1.000000 -0.298011 -0.018715 -0.024735  0.101624 -0.002569
# table  0.181685 -0.298011  1.000000  0.196206  0.182346  0.148944  0.126942
# x      0.976368 -0.018715  0.196206  1.000000  0.962715  0.956606  0.886247
# y      0.941071 -0.024735  0.182346  0.962715  1.000000  0.928923  0.856243
# z      0.940640  0.101624  0.148944  0.956606  0.928923  1.000000  0.850536
# price  0.922416 -0.002569  0.126942  0.886247  0.856243  0.850536  1.000000

# %%
sns.set_theme('paper')
for i in ['carat','depth','table','x','y','z']:
  plt.figure()
  sns.lmplot( x=i, y="price", data=cz, fit_reg=False, legend=False)
  plt.xlabel(i)
  plt.ylabel("price")
  plt.legend(loc='lower right')
  plt.title(i+" vs price")
  plt.show()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
cz
# Out:
#        carat        cut color clarity  depth  table     x     y     z  price
# 1       0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29  2.66    499
# 2       0.33    Premium     G      IF   60.8   58.0  4.42  4.46  2.70    984
# 3       0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12  3.78   6289
# 4       0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80  2.96   1082
# 5       0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43  2.65    779
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...    ...
# 26963   1.11    Premium     G     SI1   62.3   58.0  6.61  6.52  4.09   5408
# 26964   0.33      Ideal     H      IF   61.9   55.0  4.44  4.42  2.74   1114
# 26965   0.51    Premium     E     VS2   61.7   58.0  5.12  5.15  3.17   1656
# 26966   0.27  Very Good     F    VVS2   61.8   56.0  4.19  4.20  2.60    682
# 26967   1.25    Premium     J     SI1   62.0   58.0  6.90  6.88  4.27   5166
#
# [26967 rows x 10 columns]

# %%
for i in ['cut','color','clarity']:
  exec("price_vs_{} = cz[['price','{}']].groupby(['{}']).mean()".format(i,i,i))
  exec("price_vs_{}.reset_index(inplace=True)".format(i))

# %%
price_vs_color
# Out:
#   color        price
# 0     D  3185.961423
# 1     E  3073.946715
# 2     F  3699.880313
# 3     G  4002.694400
# 4     H  4486.713554
# 5     I  5129.830386
# 6     J  5331.453915

# %%
sns.set_theme('paper')
for i in ['cut','clarity','color']:
  plt.figure()
  exec("df=price_vs_{}".format(i))
  sns.barplot(data=df,x=i,y="price")
  plt.xlabel(i)
  plt.ylabel("price")
  plt.title(i+" vs price")
  plt.show()
