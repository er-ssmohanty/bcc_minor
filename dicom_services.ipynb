# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
metadata = pd.read_csv('/content/drive/MyDrive/metadata.csv')
metadata.tail()

# %%
study_id = metadata['Study UID']
file_location = metadata['File Location']

# %%
metadata.columns
# Out:
# Index(['Series UID', 'Collection', '3rd Party Analysis',
#        'Data Description URI', 'Subject ID', 'Study UID', 'Study Description',
#        'Study Date', 'Series Description', 'Manufacturer', 'Modality',
#        'SOP Class Name', 'SOP Class UID', 'Number of Images', 'File Size',
#        'File Location', 'Download Timestamp'],
#       dtype='object')

# %%
metadata.Modality.value_counts()
# Out:
# MG    6717
# Name: Modality, dtype: int64

# %%
df1=pd.read_csv("/content/drive/MyDrive/mass_case_description_train_set.csv")

# %%
df1.head()
# Out:
#   patient_id  breast_density left or right breast image view  abnormality id  \
# 0    P_00001               3                 LEFT         CC               1
# 1    P_00001               3                 LEFT        MLO               1
# 2    P_00004               3                 LEFT         CC               1
# 3    P_00004               3                 LEFT        MLO               1
# 4    P_00004               3                RIGHT        MLO               1
#
#   abnormality type                          mass shape   mass margins  \
# 0             mass  IRREGULAR-ARCHITECTURAL_DISTORTION     SPICULATED
# 1             mass  IRREGULAR-ARCHITECTURAL_DISTORTION     SPICULATED
# 2             mass            ARCHITECTURAL_DISTORTION    ILL_DEFINED
# 3             mass            ARCHITECTURAL_DISTORTION    ILL_DEFINED
# 4             mass                                OVAL  CIRCUMSCRIBED
#
#    assessment  pathology  subtlety  \
# 0           4  MALIGNANT         4
# ...

# %%
df1['image file path'][0]
# Out:
# 'Mass-Training_P_00001_LEFT_CC/1.3.6.1.4.1.9590.100.1.2.422112722213189649807611434612228974994/1.3.6.1.4.1.9590.100.1.2.342386194811267636608694132590482924515/000000.dcm'

# %%
varstr=df1['image file path'][0]

# %%
varstr.split("/")[1]
# Out:
# '1.3.6.1.4.1.9590.100.1.2.422112722213189649807611434612228974994'

# %%
cnt=0
for i in df1['image file path']:
  for j in metadata['Study UID']:
    if i.split("/")[1]==j:
      cnt+=1
print(cnt)
# Out:
# 1318

# %%
mv database.rar drive/MyDrive

# %%
# !wget http://visual.ic.uff.br/proeng/thiagoelias/database.rar
# Out:
# --2022-10-22 16:55:05--  http://visual.ic.uff.br/proeng/thiagoelias/database.rar
# Resolving visual.ic.uff.br (visual.ic.uff.br)... 200.20.15.38
# Connecting to visual.ic.uff.br (visual.ic.uff.br)|200.20.15.38|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 483263536 (461M)
# Saving to: ‘database.rar’
#
# database.rar        100%[===================>] 460.88M  10.3MB/s    in 48s
#
# 2022-10-22 16:55:55 (9.65 MB/s) - ‘database.rar’ saved [483263536/483263536]

# %%
tar -xz

# %%
pip install patool
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 77 kB 3.0 MB/s
# ...

# %%
mkdir thermograms

# %%
import patoolib
patoolib.extract_archive("database.rar", outdir="thermograms")
# Out:
# patool: Extracting database.rar ...
# patool: running /usr/bin/unrar x -- /content/drive/MyDrive/database.rar
# patool:     with cwd='thermograms'
# patool: ... database.rar extracted to `thermograms'.
# 'thermograms'

# %%
df1['cropped image file path'][0]
# Out:
# 'Mass-Training_P_00001_LEFT_CC_1/1.3.6.1.4.1.9590.100.1.2.108268213011361124203859148071588939106/1.3.6.1.4.1.9590.100.1.2.296736403313792599626368780122205399650/000000.dcm'

# %%
df1['ROI mask file path'][0]
# Out:
# 'Mass-Training_P_00001_LEFT_CC_1/1.3.6.1.4.1.9590.100.1.2.108268213011361124203859148071588939106/1.3.6.1.4.1.9590.100.1.2.296736403313792599626368780122205399650/000001.dcm\n'

# %%
len(df1['image file path'][i])
# Out:
# 169

# %%
metadata['Study UID'][10]
# Out:
# '1.3.6.1.4.1.9590.100.1.2.261142802012312819739743387111814412775'

# %%
metadata['File Location'][0]
# Out:
# '.\\CBIS-DDSM\\Calc-Test_P_00038_LEFT_CC_1\\08-29-2017-DDSM-NA-94942\\1.000000-ROI mask images-18515'
